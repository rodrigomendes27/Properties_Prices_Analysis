# %% [markdown]
# # 1. Data Acquisition

# %%
import pandas as pd
import numpy as py

# %%
df = pd.read_csv(r"\Users\Rodrigo Mendes\Desktop\Dados_de_custo_de_casas.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # 2. Pre-processing

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
# Function to differentiate data from "SalePrice" higher than or equal to $ 220,000.00

def transformar(x:int):
  if x >= int("220000"):
    
    """This function returns 1 if the parameter be
    higher than 220000 or 0 if not
    
    :param int x: first int number
    
    :return: 1 or 0
    :rtype: int"""
    
    return 1
  else:
    return 0

# %%
df["Response"] = df["SalePrice"].map(transformar)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave     0      Reg
# 1   2          20       RL         80.0     9600   Pave     0      Reg
# 2   3          60       RL         68.0    11250   Pave     0      IR1
# 3   4          70       RL         60.0     9550   Pave     0      IR1
# 4   5          60       RL         84.0    14260   Pave     0      IR1
#
#   LandContour Utilities  ... PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...      0     0           0       0      2   2008
# 1         Lvl    AllPub  ...      0     0           0       0      5   2007
# 2         Lvl    AllPub  ...      0     0           0       0      9   2008
# 3         Lvl    AllPub  ...      0     0           0       0      2   2006
# 4         Lvl    AllPub  ...      0     0           0       0     12   2008
#
#   SaleType  SaleCondition  SalePrice  Response
# ...

# %%
# Correlation Matrix

df.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
# ...

# %%
df.iloc[:, :].corr()["Response"]
# Out:
# Id              -0.028768
# MSSubClass      -0.099833
# LotFrontage      0.305691
# LotArea          0.240110
# OverallQual      0.644950
# OverallCond     -0.083932
# YearBuilt        0.392397
# YearRemodAdd     0.396573
# MasVnrArea       0.371623
# BsmtFinSF1       0.284700
# BsmtFinSF2      -0.017101
# BsmtUnfSF        0.195633
# TotalBsmtSF      0.486742
# 1stFlrSF         0.488909
# 2ndFlrSF         0.252330
# LowQualFinSF    -0.034111
# GrLivArea        0.566142
# BsmtFullBath     0.179265
# BsmtHalfBath    -0.058131
# FullBath         0.426298
# HalfBath         0.176720
# BedroomAbvGr     0.112096
# KitchenAbvGr    -0.116505
# TotRmsAbvGrd     0.413840
# Fireplaces       0.366061
# GarageYrBlt      0.368794
# GarageCars       0.501468
# GarageArea       0.519303
# WoodDeckSF       0.233473
# OpenPorchSF      0.292683
# EnclosedPorch   -0.083187
# 3SsnPorch        0.032885
# ScreenPorch      0.073012
# PoolArea         0.055921
# MiscVal         -0.019397
# ...

# %% [raw]
# According to Pearson's correlation table below, the variables OverallQual, GrLivArea, GarageCars, GarageArea, TotalBsmtSF, 1stFlrSF, FullBath, TotRmsAbvGrd have a moderate correlation with the Response variable

# %% [markdown]
# ![Capturar.PNG](attachment:Capturar.PNG)

# %% [markdown]
# # 3. Pre processing

# %%
df.fillna(0,inplace = True)

# %%
from sklearn.model_selection import train_test_split

label = df["Response"]
feat_cols = df.columns.tolist()
feat_cols.remove("Response")
feat = df[feat_cols]

X_train, X_test, y_train, y_test = train_test_split(feat, label, random_state=1)

# %%
df.select_dtypes(include='object')
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave     0      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave     0      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave     0      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave     0      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave     0      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave     0      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave     0      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave     0      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave     0      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave     0      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 82 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = dict()
cat_cols = ["MSZoning", "Street", "Alley", "LotShape", "LandContour", "Utilities", "LotConfig", "LandSlope", "Neighborhood", "Condition1", "Condition2", "BldgType", "HouseStyle", "RoofStyle", "RoofMatl", "Exterior1st", "Exterior2nd", "MasVnrType", "ExterQual", "ExterCond", "Foundation", "BsmtQual", "BsmtCond", "BsmtExposure", "BsmtFinType1", "BsmtFinType2", "Heating", "HeatingQC", "CentralAir", "Electrical", "KitchenQual", "Functional", "FireplaceQu", "GarageType", "GarageFinish", "GarageQual", "GarageCond", "PavedDrive", "PoolQC", "Fence", "MiscFeature", "SaleType", "SaleCondition"]
for col in cat_cols:
  le[col] = LabelEncoder()
  X_train[col] = le[col].fit_transform(X_train[col].astype(str))
# Out:
# <ipython-input-263-d15b1b648e9c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[col] = le[col].fit_transform(X_train[col].astype(str))

# %%
X_train.head()
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 6        7          20         3         75.0    10084       1      0
# 807    808          70         3        144.0    21384       1      0
# 955    956          90         2         82.0     7136       1      0
# 1040  1041          20         3         88.0    13125       1      0
# 701    702          20         3         80.0     9600       1      0
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# 6            3            3          0  ...         0       0      0
# 807          3            3          0  ...         0       0      0
# 955          0            1          0  ...         0       0      0
# 1040         3            3          0  ...         0       0      1
# 701          3            3          0  ...         0       0      0
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Normalizing data
 
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
X_ = ss.fit_transform(X_train)

# %%
df["Response"].sum()/df["Response"].value_counts()
# Out:
# 0    0.303571
# 1    1.000000
# Name: Response, dtype: float64

# %% [raw]
# As it is possible to see above, only 30% of the data is higher to $ 220,000.00, therefore, the data is unbalanced

# %%
# !pip install imblearn

# %%
# Balacing data

from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_, y_ = SMOTE().fit_resample(X_, y_train)

# %% [markdown]
# # 3. Machine Learning Training Model

# %%
# !pip install xgboost

# %%
import xgboost as xgb

clf = xgb.XGBClassifier(
    n_estimators=300,
    max_depth=15,
    scale_pos_weight=100_000,
    use_label_encoder=False
)

clf.fit(X_, y_)
# Out:
# [21:27:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=15,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=300, n_jobs=8, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=100000, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %% [markdown]
# # 4. Validating Model

# %%
le = dict()

for col in cat_cols:
    le[col] = LabelEncoder()
    X_test[col] = le[col].fit_transform(X_test[col].astype(str))
# Out:
# <ipython-input-271-6fe28ae28daf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[col] = le[col].fit_transform(X_test[col].astype(str))

# %%
X_test = ss.transform(X_test)

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(clf, X_test, y_test, normalize="true")
